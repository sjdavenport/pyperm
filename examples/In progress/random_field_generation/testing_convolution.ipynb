# %%
import matplotlib.pyplot as plt
import numpy as np

grid = np.random.random((10,10))

fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, figsize=(6,10))

ax1.imshow(grid, extent=[0,100,0,1])
ax1.set_title('Default')

ax2.imshow(grid, extent=[0,100,0,1], aspect='auto')
ax2.set_title('Auto-scaled Aspect')

ax3.imshow(grid, extent=[0,200,0,1], aspect=200)
ax3.set_title('Manually Set Aspect')

plt.tight_layout()
plt.show()

# %%
grid
# Out:
# array([[6.57417461e-02, 7.87636122e-01, 5.91502431e-01, 9.40080715e-01,
#         1.27071036e-01, 8.20017829e-01, 7.17828477e-02, 9.44978894e-01,
#         3.63276497e-01, 4.60399478e-01],
#        [2.07989739e-01, 6.05709959e-01, 5.80208161e-01, 6.50745102e-01,
#         5.37801177e-02, 1.72331968e-01, 3.49707655e-01, 5.31875233e-01,
#         4.80242812e-01, 3.53484502e-01],
#        [1.41724143e-01, 3.65497314e-01, 7.78910139e-01, 4.69388006e-01,
#         4.28888564e-01, 2.32029351e-01, 3.87522022e-01, 3.19343462e-01,
#         6.44189240e-01, 8.73409940e-01],
#        [3.17042840e-01, 7.85181317e-01, 1.43407101e-01, 6.35970460e-02,
#         3.01924217e-02, 2.07512686e-01, 5.36594522e-01, 1.47577323e-01,
#         9.58447492e-02, 6.53232762e-01],
#        [5.03453667e-01, 3.72357833e-02, 9.50740074e-01, 7.79875459e-04,
#         3.13508399e-01, 3.50106415e-01, 1.65377877e-01, 3.70847253e-01,
#         5.53419812e-01, 9.50570086e-01],
#        [2.86763520e-01, 6.96060013e-01, 1.94490859e-01, 4.60106811e-01,
#         8.98628216e-01, 1.59685267e-01, 1.38226880e-01, 5.42664365e-01,
#         6.94781779e-01, 1.58798726e-01],
#        [6.50442122e-01, 3.72779175e-01, 4.61032384e-01, 1.29334873e-01,
#         9.37081264e-01, 7.63520390e-01, 6.07548013e-01, 9.37813160e-01,
#         8.38269494e-01, 8.83909282e-01],
#        [6.60247014e-01, 9.83940590e-01, 6.48203603e-01, 5.96008905e-01,
#         1.24299217e-03, 6.79724133e-01, 5.61567896e-01, 3.96774101e-01,
#         1.44139407e-01, 9.78889731e-01],
#        [5.23150361e-04, 2.31056863e-01, 1.37648515e-01, 4.81970506e-01,
#         8.07404789e-01, 2.19781553e-01, 5.02502071e-01, 8.75657987e-01,
#         4.87164260e-01, 3.03756970e-01],
#        [8.93949493e-01, 8.24882694e-01, 8.96086786e-01, 8.95996729e-01,
#         4.02733027e-01, 1.66633316e-01, 4.93733404e-02, 4.08916966e-01,
#         8.48139818e-01, 9.95636861e-01]])

# %%
y = np.array()
y[np.array([0,2,4]), np.array([0,1,2])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-21719887131f> in <module>
# ----> 1 y[np.array([0,2,4]), np.array([0,1,2])]
#
# NameError: name 'y' is not defined
